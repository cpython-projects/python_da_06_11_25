# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greetings(name):
  res = f'Hello, {name.title()}'
  return res

# %%
id(greetings)
# Out:
# 137469253504832

# %%
type(greetings)
# Out:
# function

# %%
greetings('oleh')
# Out:
# 'Hello, Oleh'

# %%
greetings('ALICE')
# Out:
# 'Hello, Alice'

# %%
def add(a, b, c):
  return a + b * c

# %%
add(6, 7, 8)
# Out:
# 62

# %%
def add(a, b, c=1):
  return a + b * c

# %%
add(5, 7)
# Out:
# 12

# %%
add(5, 7, 4)
# Out:
# 33

# %%
def add(a=5, b, c):
  return a + b * c
# Out:
#   File "/tmp/ipython-input-3846646411.py", line 1
#     def add(a=5, b, c):
#                  ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
def add(a, b):
  return a + b * c

# %%
add(3, 4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3429078788.py in <cell line: 0>()
# ----> 1 add(3, 4)
#
# /tmp/ipython-input-609302835.py in add(a, b)
#       1 def add(a, b):
# ----> 2   return a + b * c
#
# NameError: name 'c' is not defined

# %%
c = 7
add(6, 7)
# Out:
# 55

# %%
def calc(a, b, operation='+'):
  if operation == '+':
    return a + b
  if operation == '-':
    return a - b
  if operation == '*':
    return a * b
  if operation == '/':
    return a / b

# %%
calc(7, 8, '*')
# Out:
# 56

# %%
def add(a, b):
  return a + b

# %%
def add(a, b):
  if not isinstance(a, int | float):
    raise TypeError('a must be int or float')
  if not isinstance(b, int | float):
    raise TypeError('b must be int or float')

  return a + b

# %%
def add(a: int | float, b: int | float) -> int | float:
  """
  Returns sum of two numbers.

  Args:
    a: first number
    b: second number

  Returns:
    sum of a and b
  """
  return a + b

# %%
res = add(6, '7') + 'Hello'

# %%
keys = [
    'order_id', 'customer_id', 'product_id', 'product_name', 'category', 'price',
    'quantity', 'weight', 'discount', 'shipping_cost', 'payment_method',
    'delivery_status', 'customer_city', 'customer_state', 'customer_country',
    'return_requested', 'review_score', 'days_to_deliver'
    ]

data = [
	 (1001, 'C101', 'P001', 'Smartphone X', 'Electronics', 599.99, 1, '0.5kg', 0.1, 5.99, 'Credit Card', 'Delivered', 'New York', 'NY', 'USA', 0, 5.0, 3.0),
	 (1002, 'C102', 'P002', 'Laptop Pro', 'Electronics', 1299.99, 1, '2.2kg', 0.15, 12.99, 'paypal', 'Delivered', 'los angeles', 'CA', 'USA', 1, 4.0, 5.0),
	 (1003, 'C103', 'P003', 'Wireless Earbuds', 'Electronics', 79.99, 2, '0.1kg', 0.0, None, 'Credit Card', 'Shipped', 'Chicago', 'IL', 'USA', 0, None, None),
	 (1004, 'C104', 'P004', 'Smart Watch', 'Electronics', 199.99, 1, '0.3kg', 0.05, 4.99, 'debit', 'Delivered', 'Houston', 'TX', 'USA', 0, 5.0, 4.0),
	 (1005, 'C105', 'P005', 'Tablet Mini', 'Electronics', 299.99, 1, '0.7kg', None, 6.99, 'credit', 'Processing', 'PHOENIX', 'AZ', 'USA', 1, 2.0, None),
	 (1006, 'C106', 'P006', 'Bluetooth Speaker', 'Electronics', 59.99, 3, '1.1lbs', 0.0, 8.99, 'PayPal', 'Delivered', 'Philadelphia', 'PA', 'USA', 0, 4.0, 6.0),
	 (1007, 'C107', 'P007', 'Fitness Tracker', 'Electronics', 49.99, 1, '0.05kg', 0.1, 3.49, 'Debit Card', 'Delivered', 'San Antonio', 'TX', 'USA', 0, 5.0, 3.0),
	 (1008, 'C108', 'P008', '4K TV', 'Electronics', 899.99, 1, '15.4kg', 0.25, None, 'Credit Card', 'Shipped', 'San Diego', 'CA', 'USA', 0, None, None),
	 (1009, 'C109', 'P009', 'Gaming Console', 'Electronics', 499.99, 1, '3.5kg', None, 15.99, 'Credit Card', 'Processing', 'Dallas', 'TX', 'USA', 1, 3.0, None),
	 (1010, 'C110', 'P010', 'DSLR Camera', 'Electronics', 799.99, 1, '1.2kg', 0.0, 12.99, 'PayPal', 'Delivered', 'dallas', 'CA', 'USA', 0, 5.0, 5.0),
	 (1011, 'C111', 'P011', 'Action Camera', 'Electronics', 199.99, 2, '0.3kg', 0.15, 6.99, 'Credit Card', 'Shipped', 'Austin', 'TX', 'USA', 0, 4.0, 4.0),
	 (1012, 'C112', 'P012', 'External SSD', 'Electronics', 149.99, 1, '0.1kg', 0.0, 4.99, 'Debit Card', 'delivered', 'Jacksonville', 'FL', 'USA', 0, 5.0, 3.0),
	 (1013, 'C113', 'P013', 'Wireless Mouse', 'Electronics', 29.99, 3, '0.2kg', None, None, 'PayPal', 'processing', 'Fort Worth', 'TX', 'U.S.A', 1, 1.0, None),
	 (1014, 'C114', 'P014', 'Mechanical Keyboard', 'Electronics', 99.99, 1, '1.1kg', 0.1, 8.99, 'Credit Card', 'Delivered', 'Columbus', 'OH', 'United States', 0, 4.0, 4.0),
	 (1015, 'C115', 'P015', 'Monitor 27"', 'Electronics', 249.99, 1, '5.5kg', None, 14.99, 'Debit Card', 'Shipped', 'Charlotte', 'NC', 'USA', 0, 3.0, None),
	 (1016, 'C116', 'P016', 'Printer', 'Electronics', 179.99, 1, '8.8kg', 0.2, 19.99, 'Credit Card', 'Processing', 'San Francisco', 'CA', 'USA', 0, 5.0, None),
	 (1017, 'C117', 'P017', 'Projector', 'Electronics', 349.99, 1, '3.3kg', 0.1, 12.99, 'PayPal', 'Delivered', 'Indianapolis', 'IN', 'USA', 0, 4.0, 5.0),
	 (1018, 'C118', 'P018', 'Smart Bulb', 'Smart Home', 29.99, 4, '0.2kg', 0.0, 3.99, 'Debit Card', 'Delivered', 'Seattle', 'WA', 'USA', 0, 5.0, 3.0),
	 (1019, 'C119', 'P019', 'Robot Vacuum', 'Smart Home', 299.99, 1, '4.4kg', None, None, 'Credit Card', 'Shipped', 'Denver', 'CO', 'USA', 0, 4.0, None),
	 (1020, 'C120', 'P020', 'Air Purifier', 'Smart Home', 199.99, 1, '5.5kg', 0.05, 12.99, 'PayPal', 'Processing', 'Washington', 'DC', 'USA', 0, 5.0, None),
	 (1021, 'C101', 'P001', 'Smartphone X', 'Electronics', 599.99, 1, '0.5kg', 0.1, 5.99, 'Credit Card', 'Delivered', 'N.Y.', 'NY', 'USA', 0, 5.0, 3.0),
	 (1022, 'C122', 'P022', 'Docking Station', 'Electronics', 89.99, 1, '0.4kg', 0.0, 4.99, 'debit card', 'Delivered', 'Boston', 'MA', 'USA', 0, 4.0, 4.0),
	 (1023, 'C123', 'P023', 'Webcam', 'Electronics', 69.99, 1, '0.2kg', None, None, 'PayPal', 'Shipped', 'El Paso', 'TX', 'USA', 0, 3.0, None),
	 (1024, 'C124', 'P024', 'Microphone', 'Electronics', 129.99, 1, '0.5kg', 0.1, 5.99, 'Credit Card', 'Processing', 'Nashville', 'TN', 'USA', 0, 5.0, None),
	 (1025, 'C125', 'P025', 'Graphics Tablet', 'Electronics', 89.99, 1, '0.6kg', None, 4.99, 'Debit Card', 'Delivered', 'Detroit', 'MI', 'USA', 0, 4.0, 5.0),
	 (1026, 'C126', 'P026', 'E-reader', 'Electronics', 119.99, 1, '0.3kg', 0.15, None, 'PayPal', 'Delivered', 'Portland', 'OR', 'USA', 0, 5.0, 4.0),
	 (1027, 'C127', 'P027', 'Smart Plug', 'Smart Home', 24.99, 1, '0.1kg', 0.0, 2.99, 'Credit Card', 'shipped', 'Memphis', 'TN', 'USA', 0, 4.0, None),
	 (1028, 'C128', 'P028', 'NAS Drive', 'Electronics', 299.99, 1, '1.8kg', None, None, 'Debit Card', 'processing', 'Oklahoma City', 'OK', 'USA', 0, 3.0, None),
	 (1029, 'C129', 'P029', 'VR Headset', 'Electronics', 349.99, 1, '0.7kg', 0.05, 8.99, 'PayPal', 'Delivered', 'Las Vegas', 'NV', 'USA', 0, 5.0, 4.0),
	 (1030, 'C130', 'P030', 'Drone', 'Electronics', 499.99, 1, '1.2kg', None, 12.99, 'Credit Card', 'Delivered', 'Louisville', 'KY', 'USA', 0, 4.0, 3.0),
	 (1028, 'C128', 'P028', 'NAS Drive', 'Electronics', 299.99, 1, '1.8kg', None, None, 'Debit Card', 'processing', 'Oklahoma City', 'OK', 'USA', 0, 3.0, None),
	 (1016, 'C116', 'P016', 'Printer', 'Electronics', 179.99, 1, '8.8kg', 0.2, 19.99, 'Credit Card', 'Processing', 'San Francisco', 'CA', 'USA', 0, 5.0, None),
	 (1024, 'C124', 'P024', 'Microphone', 'Electronics', 129.99, 1, '0.5kg', 0.1, 5.99, 'Credit Card', 'Processing', 'Nashville', 'TN', 'USA', 0, 5.0, None),
	 (1018, 'C118', 'P018', 'Smart Bulb', 'Smart Home', 29.99, 4, '0.2kg', 0.0, 3.99, 'Debit Card', 'Delivered', 'Seattle', 'WA', 'USA', 0, 5.0, 3.0),
	 (1009, 'C109', 'P009', 'Gaming Console', 'Electronics', 499.99, 1, '3.5kg', None, 15.99, 'Credit Card', 'Processing', 'Dallas', 'TX', 'USA', 1, 3.0, None),
	 (1007, 'C107', 'P007', 'Fitness Tracker', 'Electronics', 59.99, 1, '0.05kg', 0.1, 3.49, 'Debit Card', 'Delivered', 'San Antonio', 'TX', 'USA', 0, 5.0, 3.0),
	 (1028, 'C128', 'P028', 'NAS Drive', 'Electronics', 299.99, 2, '1.8kg', None, None, 'Debit Card', 'Processing', 'Oklahoma City', 'OK', 'USA', 0, 3.0, None),
	 (2006, 'C106', 'P006', 'Bluetooth Speaker', 'Electronics', 59.99, 3, '1.1lbs', 0.0, 8.99, 'PayPal', 'Delivered', 'Philadelphia', 'PA', 'USA', 0, 4.0, 6.0),
	 (1013, 'C113', 'P013', 'Wireless Mouse', 'Electronics', 29.99, 3, '0.2kg', None, None, 'PayPal', 'Delivered', 'Fort Worth', 'TX', 'U.S.A', 1, 1.0, None),
	 (1025, 'C125', 'P025', 'Graphics Tablet', 'Electronics', 99.99, 1, '0.6kg', None, 4.99, 'PayPal', 'Delivered', 'Detroit', 'MI', 'USA', 0, 4.0, 5.0),
]

# %%
for i, row in enumerate(data):
  data[i] = dict(zip(keys, row))


print(*data, sep='\n')
# Out:
# {'order_id': 1001, 'customer_id': 'C101', 'product_id': 'P001', 'product_name': 'Smartphone X', 'category': 'Electronics', 'price': 599.99, 'quantity': 1, 'weight': '0.5kg', 'discount': 0.1, 'shipping_cost': 5.99, 'payment_method': 'Credit Card', 'delivery_status': 'Delivered', 'customer_city': 'New York', 'customer_state': 'NY', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1002, 'customer_id': 'C102', 'product_id': 'P002', 'product_name': 'Laptop Pro', 'category': 'Electronics', 'price': 1299.99, 'quantity': 1, 'weight': '2.2kg', 'discount': 0.15, 'shipping_cost': 12.99, 'payment_method': 'paypal', 'delivery_status': 'Delivered', 'customer_city': 'los angeles', 'customer_state': 'CA', 'customer_country': 'USA', 'return_requested': 1, 'review_score': 4.0, 'days_to_deliver': 5.0}
# {'order_id': 1003, 'customer_id': 'C103', 'product_id': 'P003', 'product_name': 'Wireless Earbuds', 'category': 'Electronics', 'price': 79.99, 'quantity': 2, 'weight': '0.1kg', 'discount': 0.0, 'shipping_cost': None, 'payment_method': 'Credit Card', 'delivery_status': 'Shipped', 'customer_city': 'Chicago', 'customer_state': 'IL', 'customer_country': 'USA', 'return_requested': 0, 'review_score': None, 'days_to_deliver': None}
# {'order_id': 1004, 'customer_id': 'C104', 'product_id': 'P004', 'product_name': 'Smart Watch', 'category': 'Electronics', 'price': 199.99, 'quantity': 1, 'weight': '0.3kg', 'discount': 0.05, 'shipping_cost': 4.99, 'payment_method': 'debit', 'delivery_status': 'Delivered', 'customer_city': 'Houston', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 4.0}
# {'order_id': 1005, 'customer_id': 'C105', 'product_id': 'P005', 'product_name': 'Tablet Mini', 'category': 'Electronics', 'price': 299.99, 'quantity': 1, 'weight': '0.7kg', 'discount': None, 'shipping_cost': 6.99, 'payment_method': 'credit', 'delivery_status': 'Processing', 'customer_city': 'PHOENIX', 'customer_state': 'AZ', 'customer_country': 'USA', 'return_requested': 1, 'review_score': 2.0, 'days_to_deliver': None}
# {'order_id': 1006, 'customer_id': 'C106', 'product_id': 'P006', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'price': 59.99, 'quantity': 3, 'weight': '1.1lbs', 'discount': 0.0, 'shipping_cost': 8.99, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Philadelphia', 'customer_state': 'PA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 6.0}
# {'order_id': 1007, 'customer_id': 'C107', 'product_id': 'P007', 'product_name': 'Fitness Tracker', 'category': 'Electronics', 'price': 49.99, 'quantity': 1, 'weight': '0.05kg', 'discount': 0.1, 'shipping_cost': 3.49, 'payment_method': 'Debit Card', 'delivery_status': 'Delivered', 'customer_city': 'San Antonio', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1008, 'customer_id': 'C108', 'product_id': 'P008', 'product_name': '4K TV', 'category': 'Electronics', 'price': 899.99, 'quantity': 1, 'weight': '15.4kg', 'discount': 0.25, 'shipping_cost': None, 'payment_method': 'Credit Card', 'delivery_status': 'Shipped', 'customer_city': 'San Diego', 'customer_state': 'CA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': None, 'days_to_deliver': None}
# {'order_id': 1009, 'customer_id': 'C109', 'product_id': 'P009', 'product_name': 'Gaming Console', 'category': 'Electronics', 'price': 499.99, 'quantity': 1, 'weight': '3.5kg', 'discount': None, 'shipping_cost': 15.99, 'payment_method': 'Credit Card', 'delivery_status': 'Processing', 'customer_city': 'Dallas', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 1, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 1010, 'customer_id': 'C110', 'product_id': 'P010', 'product_name': 'DSLR Camera', 'category': 'Electronics', 'price': 799.99, 'quantity': 1, 'weight': '1.2kg', 'discount': 0.0, 'shipping_cost': 12.99, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'dallas', 'customer_state': 'CA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 5.0}
# {'order_id': 1011, 'customer_id': 'C111', 'product_id': 'P011', 'product_name': 'Action Camera', 'category': 'Electronics', 'price': 199.99, 'quantity': 2, 'weight': '0.3kg', 'discount': 0.15, 'shipping_cost': 6.99, 'payment_method': 'Credit Card', 'delivery_status': 'Shipped', 'customer_city': 'Austin', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 4.0}
# {'order_id': 1012, 'customer_id': 'C112', 'product_id': 'P012', 'product_name': 'External SSD', 'category': 'Electronics', 'price': 149.99, 'quantity': 1, 'weight': '0.1kg', 'discount': 0.0, 'shipping_cost': 4.99, 'payment_method': 'Debit Card', 'delivery_status': 'delivered', 'customer_city': 'Jacksonville', 'customer_state': 'FL', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1013, 'customer_id': 'C113', 'product_id': 'P013', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'price': 29.99, 'quantity': 3, 'weight': '0.2kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'PayPal', 'delivery_status': 'processing', 'customer_city': 'Fort Worth', 'customer_state': 'TX', 'customer_country': 'U.S.A', 'return_requested': 1, 'review_score': 1.0, 'days_to_deliver': None}
# {'order_id': 1014, 'customer_id': 'C114', 'product_id': 'P014', 'product_name': 'Mechanical Keyboard', 'category': 'Electronics', 'price': 99.99, 'quantity': 1, 'weight': '1.1kg', 'discount': 0.1, 'shipping_cost': 8.99, 'payment_method': 'Credit Card', 'delivery_status': 'Delivered', 'customer_city': 'Columbus', 'customer_state': 'OH', 'customer_country': 'United States', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 4.0}
# {'order_id': 1015, 'customer_id': 'C115', 'product_id': 'P015', 'product_name': 'Monitor 27"', 'category': 'Electronics', 'price': 249.99, 'quantity': 1, 'weight': '5.5kg', 'discount': None, 'shipping_cost': 14.99, 'payment_method': 'Debit Card', 'delivery_status': 'Shipped', 'customer_city': 'Charlotte', 'customer_state': 'NC', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 1016, 'customer_id': 'C116', 'product_id': 'P016', 'product_name': 'Printer', 'category': 'Electronics', 'price': 179.99, 'quantity': 1, 'weight': '8.8kg', 'discount': 0.2, 'shipping_cost': 19.99, 'payment_method': 'Credit Card', 'delivery_status': 'Processing', 'customer_city': 'San Francisco', 'customer_state': 'CA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': None}
# {'order_id': 1017, 'customer_id': 'C117', 'product_id': 'P017', 'product_name': 'Projector', 'category': 'Electronics', 'price': 349.99, 'quantity': 1, 'weight': '3.3kg', 'discount': 0.1, 'shipping_cost': 12.99, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Indianapolis', 'customer_state': 'IN', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 5.0}
# {'order_id': 1018, 'customer_id': 'C118', 'product_id': 'P018', 'product_name': 'Smart Bulb', 'category': 'Smart Home', 'price': 29.99, 'quantity': 4, 'weight': '0.2kg', 'discount': 0.0, 'shipping_cost': 3.99, 'payment_method': 'Debit Card', 'delivery_status': 'Delivered', 'customer_city': 'Seattle', 'customer_state': 'WA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1019, 'customer_id': 'C119', 'product_id': 'P019', 'product_name': 'Robot Vacuum', 'category': 'Smart Home', 'price': 299.99, 'quantity': 1, 'weight': '4.4kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'Credit Card', 'delivery_status': 'Shipped', 'customer_city': 'Denver', 'customer_state': 'CO', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': None}
# {'order_id': 1020, 'customer_id': 'C120', 'product_id': 'P020', 'product_name': 'Air Purifier', 'category': 'Smart Home', 'price': 199.99, 'quantity': 1, 'weight': '5.5kg', 'discount': 0.05, 'shipping_cost': 12.99, 'payment_method': 'PayPal', 'delivery_status': 'Processing', 'customer_city': 'Washington', 'customer_state': 'DC', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': None}
# {'order_id': 1021, 'customer_id': 'C101', 'product_id': 'P001', 'product_name': 'Smartphone X', 'category': 'Electronics', 'price': 599.99, 'quantity': 1, 'weight': '0.5kg', 'discount': 0.1, 'shipping_cost': 5.99, 'payment_method': 'Credit Card', 'delivery_status': 'Delivered', 'customer_city': 'N.Y.', 'customer_state': 'NY', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1022, 'customer_id': 'C122', 'product_id': 'P022', 'product_name': 'Docking Station', 'category': 'Electronics', 'price': 89.99, 'quantity': 1, 'weight': '0.4kg', 'discount': 0.0, 'shipping_cost': 4.99, 'payment_method': 'debit card', 'delivery_status': 'Delivered', 'customer_city': 'Boston', 'customer_state': 'MA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 4.0}
# {'order_id': 1023, 'customer_id': 'C123', 'product_id': 'P023', 'product_name': 'Webcam', 'category': 'Electronics', 'price': 69.99, 'quantity': 1, 'weight': '0.2kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'PayPal', 'delivery_status': 'Shipped', 'customer_city': 'El Paso', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 1024, 'customer_id': 'C124', 'product_id': 'P024', 'product_name': 'Microphone', 'category': 'Electronics', 'price': 129.99, 'quantity': 1, 'weight': '0.5kg', 'discount': 0.1, 'shipping_cost': 5.99, 'payment_method': 'Credit Card', 'delivery_status': 'Processing', 'customer_city': 'Nashville', 'customer_state': 'TN', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': None}
# {'order_id': 1025, 'customer_id': 'C125', 'product_id': 'P025', 'product_name': 'Graphics Tablet', 'category': 'Electronics', 'price': 89.99, 'quantity': 1, 'weight': '0.6kg', 'discount': None, 'shipping_cost': 4.99, 'payment_method': 'Debit Card', 'delivery_status': 'Delivered', 'customer_city': 'Detroit', 'customer_state': 'MI', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 5.0}
# {'order_id': 1026, 'customer_id': 'C126', 'product_id': 'P026', 'product_name': 'E-reader', 'category': 'Electronics', 'price': 119.99, 'quantity': 1, 'weight': '0.3kg', 'discount': 0.15, 'shipping_cost': None, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Portland', 'customer_state': 'OR', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 4.0}
# {'order_id': 1027, 'customer_id': 'C127', 'product_id': 'P027', 'product_name': 'Smart Plug', 'category': 'Smart Home', 'price': 24.99, 'quantity': 1, 'weight': '0.1kg', 'discount': 0.0, 'shipping_cost': 2.99, 'payment_method': 'Credit Card', 'delivery_status': 'shipped', 'customer_city': 'Memphis', 'customer_state': 'TN', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': None}
# {'order_id': 1028, 'customer_id': 'C128', 'product_id': 'P028', 'product_name': 'NAS Drive', 'category': 'Electronics', 'price': 299.99, 'quantity': 1, 'weight': '1.8kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'Debit Card', 'delivery_status': 'processing', 'customer_city': 'Oklahoma City', 'customer_state': 'OK', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 1029, 'customer_id': 'C129', 'product_id': 'P029', 'product_name': 'VR Headset', 'category': 'Electronics', 'price': 349.99, 'quantity': 1, 'weight': '0.7kg', 'discount': 0.05, 'shipping_cost': 8.99, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Las Vegas', 'customer_state': 'NV', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 4.0}
# {'order_id': 1030, 'customer_id': 'C130', 'product_id': 'P030', 'product_name': 'Drone', 'category': 'Electronics', 'price': 499.99, 'quantity': 1, 'weight': '1.2kg', 'discount': None, 'shipping_cost': 12.99, 'payment_method': 'Credit Card', 'delivery_status': 'Delivered', 'customer_city': 'Louisville', 'customer_state': 'KY', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 3.0}
# {'order_id': 1028, 'customer_id': 'C128', 'product_id': 'P028', 'product_name': 'NAS Drive', 'category': 'Electronics', 'price': 299.99, 'quantity': 1, 'weight': '1.8kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'Debit Card', 'delivery_status': 'processing', 'customer_city': 'Oklahoma City', 'customer_state': 'OK', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 1016, 'customer_id': 'C116', 'product_id': 'P016', 'product_name': 'Printer', 'category': 'Electronics', 'price': 179.99, 'quantity': 1, 'weight': '8.8kg', 'discount': 0.2, 'shipping_cost': 19.99, 'payment_method': 'Credit Card', 'delivery_status': 'Processing', 'customer_city': 'San Francisco', 'customer_state': 'CA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': None}
# {'order_id': 1024, 'customer_id': 'C124', 'product_id': 'P024', 'product_name': 'Microphone', 'category': 'Electronics', 'price': 129.99, 'quantity': 1, 'weight': '0.5kg', 'discount': 0.1, 'shipping_cost': 5.99, 'payment_method': 'Credit Card', 'delivery_status': 'Processing', 'customer_city': 'Nashville', 'customer_state': 'TN', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': None}
# {'order_id': 1018, 'customer_id': 'C118', 'product_id': 'P018', 'product_name': 'Smart Bulb', 'category': 'Smart Home', 'price': 29.99, 'quantity': 4, 'weight': '0.2kg', 'discount': 0.0, 'shipping_cost': 3.99, 'payment_method': 'Debit Card', 'delivery_status': 'Delivered', 'customer_city': 'Seattle', 'customer_state': 'WA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1009, 'customer_id': 'C109', 'product_id': 'P009', 'product_name': 'Gaming Console', 'category': 'Electronics', 'price': 499.99, 'quantity': 1, 'weight': '3.5kg', 'discount': None, 'shipping_cost': 15.99, 'payment_method': 'Credit Card', 'delivery_status': 'Processing', 'customer_city': 'Dallas', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 1, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 1007, 'customer_id': 'C107', 'product_id': 'P007', 'product_name': 'Fitness Tracker', 'category': 'Electronics', 'price': 59.99, 'quantity': 1, 'weight': '0.05kg', 'discount': 0.1, 'shipping_cost': 3.49, 'payment_method': 'Debit Card', 'delivery_status': 'Delivered', 'customer_city': 'San Antonio', 'customer_state': 'TX', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 5.0, 'days_to_deliver': 3.0}
# {'order_id': 1028, 'customer_id': 'C128', 'product_id': 'P028', 'product_name': 'NAS Drive', 'category': 'Electronics', 'price': 299.99, 'quantity': 2, 'weight': '1.8kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'Debit Card', 'delivery_status': 'Processing', 'customer_city': 'Oklahoma City', 'customer_state': 'OK', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 3.0, 'days_to_deliver': None}
# {'order_id': 2006, 'customer_id': 'C106', 'product_id': 'P006', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'price': 59.99, 'quantity': 3, 'weight': '1.1lbs', 'discount': 0.0, 'shipping_cost': 8.99, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Philadelphia', 'customer_state': 'PA', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 6.0}
# {'order_id': 1013, 'customer_id': 'C113', 'product_id': 'P013', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'price': 29.99, 'quantity': 3, 'weight': '0.2kg', 'discount': None, 'shipping_cost': None, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Fort Worth', 'customer_state': 'TX', 'customer_country': 'U.S.A', 'return_requested': 1, 'review_score': 1.0, 'days_to_deliver': None}
# {'order_id': 1025, 'customer_id': 'C125', 'product_id': 'P025', 'product_name': 'Graphics Tablet', 'category': 'Electronics', 'price': 99.99, 'quantity': 1, 'weight': '0.6kg', 'discount': None, 'shipping_cost': 4.99, 'payment_method': 'PayPal', 'delivery_status': 'Delivered', 'customer_city': 'Detroit', 'customer_state': 'MI', 'customer_country': 'USA', 'return_requested': 0, 'review_score': 4.0, 'days_to_deliver': 5.0}

# %%
import statistics

def shipping_cost_mean(data):
  res = [item['shipping_cost'] for item in data if item['shipping_cost'] is not None]
  avg = statistics.mean(res)

  for i, item in enumerate(data):
    if item['shipping_cost'] is None:
      data[i]['shipping_cost'] = avg

  return data




data = shipping_cost_mean(data)

# %%
def review_score_median(data):
  pass

def days_to_deliver_zero(data):
  pass

# %%
x = [1, 2, 3, 4, 5, 6]

def power_2(data):
  for i, item in enumerate(data):
    data[i] = item ** 2



power_2(x)

print(x)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/cpython-projects/da_1709/refs/heads/main/Walmart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df.Weekly_Sales.mean()
# Out:
# np.float64(1046964.8775617715)

# %%
df.Weekly_Sales.hist()
# Out:
# <Axes: >
