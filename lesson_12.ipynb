# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
class Product:
  def __init__(self, name, price):
    self.name = name
    self.price = price

  def __str__(self):
    return f'{self.name} - {self.price} UAH'

# %%
class Cart:

  def __init__(self):
    self.products = []
    self.quantities = []

  def add_product(self, product, quantity=1):
    self.products.append(product)
    self.quantities.append(quantity)

  def total_price(self):
    total = 0
    for product, quantity in zip(self.products, self.quantities):
      total += product.price * quantity
    return total

  def __str__(self):
    result = ''
    for product, quantity in zip(self.products, self.quantities):
      result += f'{product} x {quantity} = {product.price * quantity} UAH \n'
    result += f'Total: {self.total_price()} UAH'
    return result

# %%
pr_1 = Product('banana', 100)
pr_2 = Product('apple', 101)
pr_3 = Product('bread', 90)

# %%
pr_1.name
# Out:
# 'banana'

# %%
pr_1.price
# Out:
# 100

# %%
x = 'Hello'
print(x)
# Out:
# Hello

# %%
print(pr_1)
# Out:
# banana - 100 UAH

# %%
str(pr_1) # pr_1.__str__()
# Out:
# 'banana - 100 UAH'

# %%
(5).__str__()
# Out:
# '5'

# %%
cart_1 = Cart()
cart_1.add_product(pr_1, 2)
cart_1.add_product(pr_2, 3)
cart_1.add_product(pr_3, 1)

# %%
cart_1.total_price()
# Out:
# 593

# %%
print(cart_1)
# Out:
# banana - 100 UAH x 2 = 200 UAH
# apple - 101 UAH x 3 = 303 UAH
# bred - 90 UAH x 1 = 90 UAH
# Total: 593 UAH

# %% [markdown]
# # Part 2

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
x = ['one', 'two', 'three', 'four', 'five']
s = pd.Series(x)
s
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# 4     five
# dtype: object

# %%
x = {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five'}
s = pd.Series(x)
s
# Out:
# 1      one
# 2      two
# 3    three
# 4     four
# 5     five
# dtype: object

# %%
df = pd.DataFrame(x, index=[0])
df
# Out:
#      1    2      3     4     5
# 0  one  two  three  four  five

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39decd24-0ba2-410b-8074-176c4a295a41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39decd24-0ba2-410b-8074-176c4a295a41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns.to_list()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
x = df['Name']
type(x)
# Out:
# pandas.core.series.Series

# %%
df['Age']

# %%
df.rename(columns={'PassengerId': 'id'}, inplace=True)

# %%
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
df['Name'] = df['Name'].str.upper()

# %%
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            BRAUND, MR. OWEN HARRIS
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4      5         0       3                           ALLEN, MR. WILLIAM HENRY
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              MONTVILA, REV. JUOZAS
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889  890         1       1                              BEHR, MR. KARL HOWELL
# 890  891         0       3                                DOOLEY, MR. PATRICK
#
# ...

# %%
df['Age'] = df['Age'] + 10
df
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            BRAUND, MR. OWEN HARRIS
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4      5         0       3                           ALLEN, MR. WILLIAM HENRY
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              MONTVILA, REV. JUOZAS
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
# 888  889         0       3           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889  890         1       1                              BEHR, MR. KARL HOWELL
# 890  891         0       3                                DOOLEY, MR. PATRICK
#
# ...

# %%
df_filtered = df[['Name', 'Age', 'Sex', 'Survived']]
df_filtered
# Out:
#                                                   Name   Age     Sex  Survived
# 0                              BRAUND, MR. OWEN HARRIS  32.0    male         0
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  48.0  female         1
# 2                               HEIKKINEN, MISS. LAINA  36.0  female         1
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  45.0  female         1
# 4                             ALLEN, MR. WILLIAM HENRY  45.0    male         0
# ..                                                 ...   ...     ...       ...
# 886                              MONTVILA, REV. JUOZAS  37.0    male         0
# 887                       GRAHAM, MISS. MARGARET EDITH  29.0  female         1
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"   NaN  female         0
# 889                              BEHR, MR. KARL HOWELL  36.0    male         1
# 890                                DOOLEY, MR. PATRICK  42.0    male         0
#
# [891 rows x 4 columns]

# %%
df_filtered['is_adult'] = df_filtered['Age'] >= 18
df_filtered
# Out:
# /tmp/ipython-input-1671487457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['is_adult'] = df_filtered['Age'] >= 18
#                                                   Name   Age     Sex  \
# 0                              BRAUND, MR. OWEN HARRIS  32.0    male
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  48.0  female
# 2                               HEIKKINEN, MISS. LAINA  36.0  female
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  45.0  female
# 4                             ALLEN, MR. WILLIAM HENRY  45.0    male
# ..                                                 ...   ...     ...
# 886                              MONTVILA, REV. JUOZAS  37.0    male
# ...

# %%
df.Age.hist(bins=100)
# Out:
# <Axes: >

# %%
df_filtered.drop(columns=['Age'], inplace=True)
# Out:
# /tmp/ipython-input-3824324630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(columns=['Age'], inplace=True)

# %%
df_filtered
# Out:
#                                                   Name     Sex  Survived  \
# 0                              BRAUND, MR. OWEN HARRIS    male         0
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female         1
# 2                               HEIKKINEN, MISS. LAINA  female         1
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female         1
# 4                             ALLEN, MR. WILLIAM HENRY    male         0
# ..                                                 ...     ...       ...
# 886                              MONTVILA, REV. JUOZAS    male         0
# 887                       GRAHAM, MISS. MARGARET EDITH  female         1
# 888           JOHNSTON, MISS. CATHERINE HELEN "CARRIE"  female         0
# 889                              BEHR, MR. KARL HOWELL    male         1
# 890                                DOOLEY, MR. PATRICK    male         0
#
#      is_adult
# 0        True
# 1        True
# 2        True
# 3        True
# ...

# %%
df_adult = df_filtered[df_filtered['is_adult']]
df_adult
# Out:
#                                                   Name     Sex  Survived  \
# 0                              BRAUND, MR. OWEN HARRIS    male         0
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...  female         1
# 2                               HEIKKINEN, MISS. LAINA  female         1
# 3         FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)  female         1
# 4                             ALLEN, MR. WILLIAM HENRY    male         0
# ..                                                 ...     ...       ...
# 885               RICE, MRS. WILLIAM (MARGARET NORTON)  female         0
# 886                              MONTVILA, REV. JUOZAS    male         0
# 887                       GRAHAM, MISS. MARGARET EDITH  female         1
# 889                              BEHR, MR. KARL HOWELL    male         1
# 890                                DOOLEY, MR. PATRICK    male         0
#
#      is_adult
# 0        True
# 1        True
# 2        True
# 3        True
# ...

# %%
df_male = df[df['Sex'] == 'male']
df_male
# Out:
#       id  Survived  Pclass                            Name   Sex   Age  SibSp  \
# 0      1         0       3         BRAUND, MR. OWEN HARRIS  male  32.0      1
# 4      5         0       3        ALLEN, MR. WILLIAM HENRY  male  45.0      0
# 5      6         0       3                MORAN, MR. JAMES  male   NaN      0
# 6      7         0       1         MCCARTHY, MR. TIMOTHY J  male  64.0      0
# 7      8         0       3  PALSSON, MASTER. GOSTA LEONARD  male  12.0      3
# ..   ...       ...     ...                             ...   ...   ...    ...
# 883  884         0       2   BANFIELD, MR. FREDERICK JAMES  male  38.0      0
# 884  885         0       3          SUTEHALL, MR. HENRY JR  male  35.0      0
# 886  887         0       2           MONTVILA, REV. JUOZAS  male  37.0      0
# 889  890         1       1           BEHR, MR. KARL HOWELL  male  36.0      0
# 890  891         0       3             DOOLEY, MR. PATRICK  male  42.0      0
#
# ...

# %% [markdown]
# and - &
# or - |
# not - ~

# %%
df_male_adult = df[(df['Sex'] == 'male') & (df['Age'] >= 18)]
df_male_adult
# Out:
#       id  Survived  Pclass                            Name   Sex   Age  SibSp  \
# 0      1         0       3         BRAUND, MR. OWEN HARRIS  male  32.0      1
# 4      5         0       3        ALLEN, MR. WILLIAM HENRY  male  45.0      0
# 6      7         0       1         MCCARTHY, MR. TIMOTHY J  male  64.0      0
# 12    13         0       3  SAUNDERCOCK, MR. WILLIAM HENRY  male  30.0      0
# 13    14         0       3     ANDERSSON, MR. ANDERS JOHAN  male  49.0      1
# ..   ...       ...     ...                             ...   ...   ...    ...
# 883  884         0       2   BANFIELD, MR. FREDERICK JAMES  male  38.0      0
# 884  885         0       3          SUTEHALL, MR. HENRY JR  male  35.0      0
# 886  887         0       2           MONTVILA, REV. JUOZAS  male  37.0      0
# 889  890         1       1           BEHR, MR. KARL HOWELL  male  36.0      0
# 890  891         0       3             DOOLEY, MR. PATRICK  male  42.0      0
#
# ...

# %%
df_female_adult = df[(df['Sex'] == 'female') & (df['Age'] >= 18)]
df_female_adult
# Out:
#       id  Survived  Pclass                                               Name  \
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2      3         1       3                             HEIKKINEN, MISS. LAINA
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 8      9         1       3  JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)
# 9     10         1       2                NASSER, MRS. NICHOLAS (ADELE ACHEM)
# ..   ...       ...     ...                                                ...
# 879  880         1       1      POTTER, MRS. THOMAS JR (LILY ALEXENIA WILSON)
# 880  881         1       2       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)
# 882  883         0       3                       DAHLBERG, MISS. GERDA ULRIKA
# 885  886         0       3               RICE, MRS. WILLIAM (MARGARET NORTON)
# 887  888         1       1                       GRAHAM, MISS. MARGARET EDITH
#
# ...

# %%
df.Age.mean()
# Out:
# np.float64(39.69911764705882)

# %%
df.Age.median()
# Out:
# 38.0

# %%
df.Age.mode()
# Out:
# 0    34.0
# Name: Age, dtype: float64

# %%
df.Age.std()
# Out:
# 14.526497332334044

# %%
df.Age.min(), df.Age.max(), df.Age.max() - df.Age.min()
# Out:
# (10.42, 90.0, 79.58)

# %%
df.Age.sum()
# Out:
# np.float64(28345.17)

# %%
df[df.Name.str.contains('MRS')]
# Out:
#       id  Survived  Pclass                                               Name  \
# 1      2         1       1  CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 3      4         1       1       FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 8      9         1       3  JOHNSON, MRS. OSCAR W (ELISABETH VILHELMINA BERG)
# 9     10         1       2                NASSER, MRS. NICHOLAS (ADELE ACHEM)
# 15    16         1       2                   HEWLETT, MRS. (MARY D KINGCOME)
# ..   ...       ...     ...                                                ...
# 871  872         1       1   BECKWITH, MRS. RICHARD LEONARD (SALLIE MONYPENY)
# 874  875         1       2              ABELSON, MRS. SAMUEL (HANNAH WIZOSKY)
# 879  880         1       1      POTTER, MRS. THOMAS JR (LILY ALEXENIA WILSON)
# 880  881         1       2       SHELLEY, MRS. WILLIAM (IMANITA PARRISH HALL)
# 885  886         0       3               RICE, MRS. WILLIAM (MARGARET NORTON)
#
# ...
