# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_11_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task 1.** Напишіть функцію `feedback_stats(scores: list[int]) -> tuple[float, float]`, яка повертає кортеж із середньої оцінки та стандартного відхилення за шкалою від 1 до 10.
#
# *Приклад вхідних даних:*
#
# ```python
# scores = [8, 9, 7, 6, 10, 8, 9]
# ```
#
# *Приклад вихідних даних:*
#
# ```python
# (8.14, 1.24)
# ```

# %% [markdown]
# **Task 2.** Створіть функцію `is_symmetric(data: list[float]) -> bool`, яка повертає `True`, якщо середнє та медіана майже рівні (різниця < 0.1), інакше — `False`.
#
# *Приклад вхідних даних:*
#
# ```python
# data = [10, 12, 11, 13, 12]
# ```
#
# *Приклад вихідних даних:*
#
# ```python
# True
# ```

# %% [markdown]
# **Task 3.**. Напишіть функцію `sales_summary(sales: list[float]) -> dict`, яка повертає словник зі статистикою `'mean'`, `'median'`, `'stdev'`.
#
# *Приклад вхідних даних:*
#
# ```python
# sales = [10000.0, 10500.0, 9800.0, 10200.0]
# ```
#
# *Приклад вихідних даних:*
#
# ```python
# {'mean': 10125.0, 'median': 10100.0, 'stdev': 286.17}
# ```

# %% [markdown]
# **Task 4.** Реалізуйте функцію `detect_outliers(data: list[float]) -> list[float]`, яка повертає значення, що відрізняються від середнього більше ніж на 2 стандартних відхилення.
#
# *Приклад вхідних даних:*
#
# ```python
# data = [10, 12, 11, 9, 13, 70]
# ```
#
# *Приклад вихідних даних:*
#
# ```python
# [70]
# ```

# %% [markdown]
# **Task 5.**  Напишіть функцію `seasonal_trend(monthly_sales: list[float]) -> str`, яка повертає назву кварталу (Q1, Q2, Q3 або Q4), у якому середні продажі були найвищими.
#
# *Приклад вхідних даних:*
#
# ```python
# monthly_sales = [1200, 1300, 1500, 2000, 2100, 2500, 3000, 3100, 2800, 2200, 2300, 2100]
# ```
#
# *Приклад вихідних даних:*
#
# ```python
# 'Q3'
# ```

# %% [markdown]
# **Task 6.** У вас є дані про зарплати співробітників:
# 45 співробітників отримують від 50,000 до 90,000 грн на рік,
# а 5 — від 500,000 до 1,200,000 грн.
#
# *Запитання:*
#
# > Яка метрика краще відображає "середню" зарплату — `mean` чи `median`?
# > Чому?

# %% [markdown]
# **Task 7. Оцінки студентів**
# У класі з 20 студентів оцінки переважно в межах від 7 до 9, але один студент отримав 1 бал.
#
# *Запитання:*
#
# > Яку метрику доцільніше використовувати для звіту — `mean`, `median` чи `mode`?
# > У чому переваги й недоліки кожної?

# %% [markdown]
# **Task 8. Час відповіді служби підтримки**
# Більшість звернень обробляються за 10–20 хвилин, але бувають винятки до 3 годин.
#
# *Запитання:*
#
# > Яку метрику краще використовувати у щомісячному звіті — `mean`, `median` чи `stdev`?

# %% [markdown]
# **Task 9. Середня швидкість завантаження сайту**
# Є дані по завантаженню сайту в п’яти країнах: \[1.2, 2.5, 6.1, 8.3, 10.0] секунд.
#
# *Запитання:*
#
# > Яке середнє (арифметичне, геометричне чи гармонічне) найкраще підходить для представлення швидкості?

# %% [markdown]
# **Task 10. Середня конверсія рекламної кампанії**
#
# Конверсія по днях: \[0.5%, 0.4%, 0.6%, 0.5%, 10.0%].
#
# *Запитання:*
#
# > Як порахувати середню ефективність кампанії, враховуючи різкий стрибок в останній день?
# > Як пояснити маркетологу, чому *середнє значення не завжди доречне*?
