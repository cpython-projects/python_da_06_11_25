# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_26_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Завдання 1.**
#
# Знайти всі встановлення з `cpi_uah > 30` і платформою **iOS**

# %% [markdown]
# **Завдання 2.**
# Знайти **5 найдорожчих** встановлень (найвищий `cpi_uah`)

# %% [markdown]
# **Завдання 3.**
# Порахувати **кількість унікальних пристроїв** у таблиці `product_views_log`

# %% [markdown]
# **Завдання 4.**
# Знайти **користувачів**, у яких хоча б **одна покупка перевищує 2000 UAH**
