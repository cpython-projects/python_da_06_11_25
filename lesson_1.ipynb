# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(23, 45.6, 'Hello', "Python")
# Out:
# 23 45.6 Hello Python

# %% [markdown]
# # Part 1

# %%
a = int(input('a>>'))
b = int(input('b>>'))
# Out:
# a>>123
# b>>345

# %%
a + b
# Out:
# 468

# %%
4 + 6
# Out:
# 10

# %%
4 - 6
# Out:
# -2

# %%
4 * 5
# Out:
# 20

# %% [markdown]
# # Part 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2
# Out:
# 2

# %%
5 // -2
# Out:
# -3

# %%
5 % 2
# Out:
# 1

# %%
2000 * 0.2
# Out:
# 400.0

# %%
2 ** 3
# Out:
# 8

# %%
abs(-7)
# Out:
# 7

# %%
min(78, 456, 12)
# Out:
# 12

# %%
max(67, 89, 12)
# Out:
# 89

# %% [markdown]
# # Part 3

# %%
a = 2323

# %%
a = a + 1

# %%
a
# Out:
# 2324

# %%
a += 1

# %%
a
# Out:
# 2325

# %%
a = int(input('a>>'))
b = int(input('b>>'))
# Out:
# a>>45
# b>>23

# %%
print(a, '+', b, '=', a + b)
# Out:
# 45 + 23 = 68

# %%
print(f'{a} + {b} = {a + b}')
# Out:
# 45 + 23 = 68

# %%
print(12, 56, 78, 89, 45, sep=', ')
# Out:
# 12, 56, 78, 89, 45

# %%
print(12, 56, 78, 89, 45, sep='\n')
# Out:
# 12
# 56
# 78
# 89
# 45

# %%
print(12, 56, 78, 89, 45, sep='\t')
# Out:
# 12	56	78	89	45
