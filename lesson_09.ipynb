# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set

# %% [markdown]
# *  відсутні дублікати

# %% [markdown]
# *  mutable
# *  не впорядкована
# *  hashable object

# %%
x = set('Python')
x
# Out:
# {'P', 'h', 'n', 'o', 't', 'y'}

# %% [markdown]
# [index], [slice] - НЕ МОЖНА!!!

# %%
x = {0, 1, 2, 3, 78, 'Hello', (1, 2, 3)}
x
# Out:
# {(1, 2, 3), 0, 1, 2, 3, 78, 'Hello'}

# %%
x = {2, 2, 2, 2, 2, 3, 3, 3, 3, 3}
x
# Out:
# {2, 3}

# %%
x = {[1, 2, 3]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3697376654.py in <cell line: 0>()
# ----> 1 x = {[1, 2, 3]}
#
# TypeError: unhashable type: 'list'

# %%
x = set() # пуста множина

# %%
y = None

# %%
x.add(4)
x
# Out:
# {4}

# %%
y.add(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3353592471.py in <cell line: 0>()
# ----> 1 y.add(4)
#
# AttributeError: 'NoneType' object has no attribute 'add'

# %%
res = None

if res:
  print(True)
else:
  print(False)
# Out:
# False

# %%
x = {1, 2, 3, 4, 5}

2 in x
# Out:
# True

# %%
2 not in x
# Out:
# False

# %%
for item in x:
  print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
len(x)
# Out:
# 5

# %%
customer_purchases = [
    {"Customer_ID": 1001, "Product": "Laptop", "Category": "Electronics", "Purchase_Date": "2024-02-01"},
    {"Customer_ID": 1002, "Product": "Smartphone", "Category": "Electronics", "Purchase_Date": "2024-02-02"},
    {"Customer_ID": 1003, "Product": "Sofa", "Category": "Furniture", "Purchase_Date": "2024-02-03"},
    {"Customer_ID": 1001, "Product": "Tablet", "Category": "Electronics", "Purchase_Date": "2024-02-10"},
    {"Customer_ID": 1002, "Product": "Chair", "Category": "Furniture", "Purchase_Date": "2024-02-15"},
    {"Customer_ID": 1003, "Product": "Laptop", "Category": "Electronics", "Purchase_Date": "2024-02-18"},
    {"Customer_ID": 1004, "Product": "Desk", "Category": "Furniture", "Purchase_Date": "2024-02-20"},
]

# %% [markdown]
# Визначте множину всіх унікальних товарів, які були куплені.
#
# Виведіть список унікальних Customer_ID, які купили хоча б один товар із категорії "Electronics".

# %%
products = {item['Product'] for item in customer_purchases}

products
# Out:
# {'Chair', 'Desk', 'Laptop', 'Smartphone', 'Sofa', 'Tablet'}

# %%
type(products)
# Out:
# set

# %%
products = {item['Customer_ID'] for item in customer_purchases if item['Category'] == 'Electronics'}

products
# Out:
# {1001, 1002, 1003}

# %%
clients_jan = {"A123", "B404", "C222", "D111", "E909"}
clients_feb = {"C222", "E909", "F300", "G777", "H555"}

# %%
len(clients_jan | clients_feb)
# Out:
# 8

# %%
len(clients_jan & clients_feb)
# Out:
# 2

# %%
clients_jan & clients_feb
# Out:
# {'C222', 'E909'}

# %% [markdown]
# Дані:
#
# ```python
# competitors = {
#     "StoreA": {"milk": 1.2, "bread": 0.8, "eggs": 2.1},
#     "StoreB": {"milk": 1.1, "bread": 0.9, "eggs": 2.0},
#     "StoreC": {"milk": 1.3, "bread": 0.85, "eggs": 2.05}
# }
# ```
#
# Завдання: для кожного товару знайди середню ціну на ринку. Виведи результат у вигляді словника: `{"milk": ..., "bread": ..., "eggs": ...}`
