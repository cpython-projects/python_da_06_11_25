# %% [markdown]
# <a href="https://colab.research.google.com/github/cpython-projects/python_da_06_11_25/blob/main/lesson_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# %%
DB_NAME = 'school.db'

# %%
conn = sqlite3.connect(DB_NAME)

# %%
conn

# %%
curr = conn.cursor()

# %%
create_student_table = """
CREATE TABLE IF NOT EXISTS students (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    first_name TEXT NOT NULL,
    last_name TEXT NOT NULL,
    date_of_birth DATE NOT NULL,
    phone_number TEXT NOT NULL,
    email TEXT NOT NULL
);
"""

# %%
create_student_table
# Out:
# '\nCREATE TABLE IF NOT EXISTS students (\n    id INTEGER PRIMARY KEY AUTOINCREMENT,\n    first_name TEXT NOT NULL,\n    last_name TEXT NOT NULL, \n    date_of_birth DATE NOT NULL,\n    phone_number TEXT NOT NULL,\n    email TEXT NOT NULL,\n);\n'

# %%
curr.execute(create_student_table)

# %%
create_instructors_table = """
CREATE TABLE IF NOT EXISTS instructors (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    first_name TEXT NOT NULL,
    last_name TEXT NOT NULL
);
"""

curr.execute(create_instructors_table)

# %%
create_courses_table = """
CREATE TABLE IF NOT EXISTS courses (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL
);
"""

curr.execute(create_courses_table)

# %%
create_groups_table = """
CREATE TABLE IF NOT EXISTS groups (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    title TEXT NOT NULL,
    course_id INTEGER NOT NULL,
    FOREIGN KEY (course_id) REFERENCES courses(id)
);
"""

curr.execute(create_groups_table)

# %%
create_students_in_groups_table = """
CREATE TABLE IF NOT EXISTS students_in_groups (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    student_id INTEGER NOT NULL,
    group_id INTEGER NOT NULL,
    FOREIGN KEY (student_id) REFERENCES students(id)
    FOREIGN KEY (group_id) REFERENCES groups(id)
);
"""

curr.execute(create_students_in_groups_table)

# %%
create_instructors_in_groups_table = """
CREATE TABLE IF NOT EXISTS instructors_in_groups (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    instructor_id INTEGER NOT NULL,
    group_id INTEGER NOT NULL,
    FOREIGN KEY (instructor_id) REFERENCES instructors(id)
    FOREIGN KEY (group_id) REFERENCES groups(id)
);
"""

curr.execute(create_instructors_in_groups_table)

# %%
conn.close()

# %%
from google.colab import files

# %%
files.download('school.db')

# %%
import pandas as pd

# %%
conn = sqlite3.connect(DB_NAME)

# %%
df = pd.read_sql_query('SELECT * FROM students', conn)

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, first_name, last_name, date_of_birth, phone_number, email]
# Index: []
